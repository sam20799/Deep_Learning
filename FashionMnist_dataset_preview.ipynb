# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader

# %%
train_data = datasets.FashionMNIST(root="data",train=True,download=True,transform=transforms.ToTensor())
test_data = datasets.FashionMNIST(root="data",train=False,download=True,transform=transforms.ToTensor())

# %%
train_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

# %%
image,label = train_data[0]
def show_image(image,label):
    plt.figure(figsize=(2,2))
    plt.imshow(image.squeeze(),cmap = 'Blues')
    plt.title(labels_map[label])
    plt.axis("off")
    plt.show()
show_image(image,label)

# %%
torch.randint(len(train_data),(1,)).item()
# Out:
# 31355

# %%
row,col = 3,3
figure,axes = plt.subplots(row,col,figsize=(5,5))
axes = axes.flatten()
figure.suptitle("Sample Images")

for ax in axes:
    idx = torch.randint(len(train_data),(1,)).item()
    image,label = train_data[idx]
    ax.imshow(image.squeeze(),cmap="Blues")
    ax.set_title(labels_map[label],fontsize=10)
    ax.axis("off")
plt.show()

# %%
train_loader = DataLoader(dataset=train_data,batch_size=64,shuffle=True)
test_loader = DataLoader(dataset=test_data,batch_size=64,shuffle=True)

# %%
images,labels = next(iter(train_loader))
len(images),len(labels)
# Out:
# (64, 64)

# %%
total_batch = 0
for images,labels in train_loader:
    total_batch +=1
print(f"total no of batches-> {total_batch}")
# Out:
# total no of batches-> 938

# %%
#first batch

for images,labels in train_loader:
    print(len(images))
    break;
# Out:
# 64

# %%
show_image(images[0],label])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 show_image(images[0],labels_map[labels[0].item()])
#
# Cell In[61], line 5, in show_image(image, label)
#       3 plt.figure(figsize=(2,2))
#       4 plt.imshow(image.squeeze(),cmap = 'Blues')
# ----> 5 plt.title(labels_map[label])
#       6 plt.axis("off")
#       7 plt.show()
#
# KeyError: 'Bag'
